# %% [markdown]
# ##### How to split by HTML header
# HTMLHeaderTextSplitter is a "structure-aware" chunker that splits text at the HTML element level and adds metadata for each header "relevant" to any given chunk. It can return chunks element by element or combine elements with the same metadata, with the objectives of (a) keeping related text grouped (more or less) semantically and (b) preserving context-rich information encoded in document structures. It can be used with other text splitters as part of a chunking pipeline.

# %%
url="https://en.wikipedia.org/wiki/Red_panda"

# %%
headers_to_split_on=[

	("h1","Header 1"),
	("h2","Header 2"),
	("h3","Header 3"),
]

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
splitter=HTMLHeaderTextSplitter(headers_to_split_on)

# %%
docs=splitter.split_text_from_url(url)

# %%
for doc in docs[:3]:
	print(doc)
	print("*"*100)
# Out:
# page_content='Jump to content
# Main menu
# Main menu
# move to sidebar
# hide
# Navigation
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Contribute
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# Special pages
# Search
# Search
# Appearance
# Donate
# Create account
# Log in
# Personal tools
# Donate
# Create account
# Log in
# Pages for logged out editors
# learn more
# Contributions
# Talk
# CentralNotice'
# ****************************************************************************************************
# page_content='Contents' metadata={'Header 2': 'Contents'}
# ****************************************************************************************************
# page_content='move to sidebar
# hide
# (Top)
# 1
# Etymology
# 2
# Taxonomy
# Toggle Taxonomy subsection
# 2.1
# Subspecies and species
# 2.2
# Phylogeny
# 2.3
# Fossil record
# 2.4
# Genomics
# 3
# Description
# 4
# Distribution and habitat
# 5
# Behaviour and ecology
# Toggle Behaviour and ecology subsection
# 5.1
# Social spacing
# 5.2
# Diet and feeding
# 5.3
# Communication
# 5.4
# Reproduction and parenting
# 5.5
# Mortality and diseases
# 6
# Threats
# 7
# Conservation
# Toggle Conservation subsection
# 7.1
# In captivity
# 8
# Cultural significance
# 9
# Notes
# 10
# References
# 11
# External links
# Toggle the table of contents
# Red panda
# 107 languages
# Afrikaans
# العربية
# অসমীয়া
# Asturianu
# Авар
# Azərbaycanca
# تۆرکجه
# Basa Bali
# বাংলা
# Беларуская
# Беларуская (тарашкевіца)
# Български
# བོད་ཡིག
# Brezhoneg
# Català
# Cebuano
# Čeština
# Cymraeg
# Dansk
# Deutsch
# Diné bizaad
# Dolnoserbski
# ཇོང་ཁ
# Eesti
# Ελληνικά
# Español
# Esperanto
# Euskara
# فارسی
# Français
# Gaeilge
# Gagauz
# Galego
# ગુજરાતી
# 한국어
# Հայերեն
# हिन्दी
# Hornjoserbsce
# Hrvatski
# Bahasa Indonesia
# Ирон
# Íslenska
# Italiano
# עברית
# Jawa
# ქართული
# कॉशुर / کٲشُر
# Қазақша
# Kotava
# Кыргызча
# Кырык мары
# Лакку
# Latviešu
# Лезги
# Lietuvių
# La .lojban.
# Magyar
# Македонски
# മലയാളം
# मराठी
# მარგალური
# مصرى
# Bahasa Melayu
# Монгол
# မြန်မာဘာသာ
# Nederlands
# नेपाली
# 日本語
# Нохчийн
# Nordfriisk
# Norsk bokmål
# Occitan
# Олык марий
# ଓଡ଼ିଆ
# Oʻzbekcha / ўзбекча
# ਪੰਜਾਬੀ
# پنجابی
# Перем коми
# Polski
# Português
# Română
# Русский
# Саха тыла
# ᱥᱟᱱᱛᱟᱲᱤ
# Scots
# Shqip
# Sicilianu
# Simple English
# Slovenščina
# کوردی
# Српски / srpski
# Srpskohrvatski / српскохрватски
# Suomi
# Svenska
# Tagalog
# தமிழ்
# ไทย
# Türkçe
# Удмурт
# Українська
# ئۇيغۇرچە / Uyghurche
# Tiếng Việt
# Võro
# Winaray
# 吴语
# 粵語
# 中文
# Edit links
# Article
# Talk
# English
# Read
# View source
# View history
# Tools
# Tools
# move to sidebar
# hide
# Actions
# Read
# View source
# View history
# General
# What links here
# Related changes
# Upload file
# Permanent link
# Page information
# Cite this page
# Get shortened URL
# Download QR code
# Print/export
# Download as PDF
# Printable version
# In other projects
# Wikimedia Commons
# Wikispecies
# Wikidata item
# Appearance
# move to sidebar
# hide
# From Wikipedia, the free encyclopedia
# esi <esi:include src="/esitest-fa8a495983347898/content" />
# Species of mammal in Asia
# .mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}@media print{body.ns-0 .mw-parser-output .hatnote{display:none!important}}
# For other uses, see .
# Red Panda
# Red panda
# Temporal range:
# Pleistocene–Present
# PreꞒ
# Ꞓ
# O
# S
# D
# C
# P
# T
# J
# K
# Pg
# N
# ↓
# Conservation status
# Endangered
# ( )
# IUCN 3.1
# 1
# [
# ]
# Appendix I
# CITES
# ( )
# CITES
# 1
# [
# ]
# Scientific classification
# Domain:
# Eukaryota
# Kingdom:
# Animalia
# Phylum:
# Chordata
# Class:
# Mammalia
# Order:
# Carnivora
# Family:
# Ailuridae
# Genus:
# Ailurus
# , 1825
# F. Cuvier
# Species:
# A. fulgens
# Binomial name
# Ailurus fulgens
# F. Cuvier, 1825
# Subspecies
# A. f. fulgens
# F. Cuvier, 1825
# A. f. styani
# , 1902
# Thomas
# 2
# [
# ]
# Range of the red panda
# @media(max-width:640px){body:not(.skin-minerva) .mw-parser-output .infobox{width:100%!important}body:not(.skin-minerva) .mw-parser-output .infobox th{width:50%}}@media screen{html.skin-theme-clientpref-night .mw-parser-output .infobox.biota tr{background:transparent!important}html.skin-theme-clientpref-night .mw-parser-output .infobox.biota img{background:transparent}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .infobox.biota tr{background:transparent!important}html.skin-theme-clientpref-os .mw-parser-output .infobox.biota img{background:white}}.mw-parser-output .infobox.biota .taxobox-edit-taxonomy img{background:transparent!important}body.skin-vector .mw-parser-output table.biota.infobox{margin-top:0.5em}body.skin--responsive .mw-parser-output table.biota.infobox tr.taxonrow2 td{padding:2px 10px}
# The ( ), also known as the , is a small native to the and . It has dense reddish-brown fur with a black belly and legs, white-lined ears, a mostly white muzzle and a ringed tail. Its head-to-body length is 51–63.5 cm (20.1–25.0 in) with a 28–48.5 cm (11.0–19.1 in) tail, and it weighs between 3.2 and 15 kg (7.1 and 33.1 lb). It is well adapted to climbing due to its flexible joints and curved semi-retractile claws.
# red panda
# Ailurus fulgens
# lesser panda
# mammal
# eastern Himalayas
# southwestern China
# The red panda was formally in 1825. The two currently recognised subspecies, the Himalayan and the Chinese red panda, about 250,000 years ago. The red panda's place on the has been debated, but modern genetic evidence places it in close affinity with , , and . It is not closely related to the , which is a , though both possess elongated wrist bones or " " used for grasping . The evolutionary of the red panda ( ) stretches back around , as indicated by extinct fossil relatives found in Eurasia and North America.
# described
# genetically diverged
# evolutionary tree
# raccoons
# weasels
# skunks
# giant panda
# bear
# false thumbs
# bamboo
# lineage
# Ailuridae
# million years ago
# 25 to 18
# The red panda inhabits as well as , favouring steep slopes with dense bamboo cover close to water sources. It is solitary and largely . It feeds mainly on and leaves, but also on fruits and blossoms. Red pandas mate in early spring, with the females giving birth to litters of up to four cubs in summer. It is threatened by as well as and of habitat due to . The species has been listed as on the since 2015. It is protected in all .
# coniferous forests
# temperate broadleaf and mixed forests
# arboreal
# bamboo shoots
# poaching
# destruction
# fragmentation
# deforestation
# Endangered
# IUCN Red List
# range countries
# programmes have been initiated in , and ; in China, it benefits from projects. Regional programmes for the red panda have been established in zoos around the world. It is featured in animated movies, video games, comic books and as the namesake of companies and music bands.
# Community-based conservation
# Nepal
# Bhutan
# northeastern India
# nature conservation
# captive breeding
# NewPP limit report
# Parsed by mw‐web.codfw.main‐759df5576c‐jqh6t
# Cached time: 20250515205742
# Cache expiry: 2592000
# Reduced expiry: false
# Complications: [vary‐revision‐sha1, show‐toc]
# CPU time usage: 2.409 seconds
# Real time usage: 2.821 seconds
# Preprocessor visited node count: 40615/1000000
# Post‐expand include size: 1277672/2097152 bytes
# Template argument size: 119850/2097152 bytes
# Highest expansion depth: 28/100
# Expensive parser function count: 33/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 504883/5000000 bytes
# Lua time usage: 1.520/10.000 seconds
# Lua memory usage: 20563204/52428800 bytes
# Number of Wikibase entities loaded: 22/500 Transclusion expansion time report (%,ms,calls,template)
# 100.00% 2349.166      1 -total
#  33.24%  780.895      2 Template:Reflist
#  22.65%  532.043      1 Template:Speciesbox
#  22.39%  526.024      1 Template:Taxobox/core
#  21.24%  499.079     78 Template:Cite_journal
#  10.55%  247.851     18 Template:Clade
#   9.18%  215.674      1 Template:Taxonbar
#   9.07%  213.158      1 Template:Carnivora
#   7.48%  175.757     76 Template:Period_start
#   5.65%  132.824      2 Template:Phanerozoic_220px Saved in parser cache with key enwiki:pcache:26441:|#|:idhash:canonical and timestamp 20250515205742 and revision id 1284061996. Rendering was triggered because: page-view'
# ****************************************************************************************************
